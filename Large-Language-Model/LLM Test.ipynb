# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 1024 # what is the maximum context length for predictions?
max_iters = 50000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0

torch.manual_seed(1337)

with open('./mahabharata.txt', 'r', encoding='utf-8') as f:
    text = f.read()

chars = sorted(list(set(text)))
vocab_size = len(chars)
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data))
train_data = data[:n]
val_data = data[n:]

def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        v = self.value(x) # (B,T,C)
        out = wei @ v 
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -block_size:]
            logits, loss = self(idx_cond)
            logits = logits[:, -1, :] # becomes (B, C)
            probs = F.softmax(logits, dim=-1) # (B, C)
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')

optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    xb, yb = get_batch('train')

    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# 0.275281 M parameters
# step 0: train loss 4.5788, val loss 4.5778
# step 100: train loss 2.5386, val loss 2.5492
# step 200: train loss 2.4407, val loss 2.4512
# step 300: train loss 2.4102, val loss 2.4196
# step 400: train loss 2.3970, val loss 2.4050
# step 500: train loss 2.3889, val loss 2.3991
# step 600: train loss 2.3803, val loss 2.3929
# step 700: train loss 2.3777, val loss 2.3892
# step 800: train loss 2.3724, val loss 2.3831
# step 900: train loss 2.3677, val loss 2.3800
# step 1000: train loss 2.3615, val loss 2.3750
# step 1100: train loss 2.3463, val loss 2.3590
# step 1200: train loss 2.3228, val loss 2.3344
# step 1300: train loss 2.2880, val loss 2.3000
# step 1400: train loss 2.2341, val loss 2.2444
# step 1500: train loss 2.1880, val loss 2.1982
# step 1600: train loss 2.0907, val loss 2.1049
# step 1700: train loss 2.0165, val loss 2.0289
# step 1800: train loss 1.9581, val loss 1.9726
# step 1900: train loss 1.9016, val loss 1.9163
# step 2000: train loss 1.8475, val loss 1.8670
# step 2100: train loss 1.8140, val loss 1.8326
# step 2200: train loss 1.7849, val loss 1.8082
# step 2300: train loss 1.7511, val loss 1.7695
# step 2400: train loss 1.7171, val loss 1.7429
# step 2500: train loss 1.6753, val loss 1.6978
# step 2600: train loss 1.6539, val loss 1.6764
# step 2700: train loss 1.6411, val loss 1.6664
# step 2800: train loss 1.6219, val loss 1.6493
# step 2900: train loss 1.6016, val loss 1.6273
# step 3000: train loss 1.5777, val loss 1.6057
# step 3100: train loss 1.5633, val loss 1.5852
# step 3200: train loss 1.5496, val loss 1.5764
# step 3300: train loss 1.5390, val loss 1.5713
# step 3400: train loss 1.5237, val loss 1.5576
# step 3500: train loss 1.5137, val loss 1.5440
# step 3600: train loss 1.5045, val loss 1.5369
# step 3700: train loss 1.5016, val loss 1.5311
# step 3800: train loss 1.4921, val loss 1.5225
# step 3900: train loss 1.4706, val loss 1.5042
# step 4000: train loss 1.4775, val loss 1.5116
# step 4100: train loss 1.4606, val loss 1.4929
# step 4200: train loss 1.4527, val loss 1.4893
# step 4300: train loss 1.4434, val loss 1.4742
# step 4400: train loss 1.4435, val loss 1.4735
# step 4500: train loss 1.4332, val loss 1.4638
# step 4600: train loss 1.4292, val loss 1.4641
# step 4700: train loss 1.4251, val loss 1.4612
# step 4800: train loss 1.4198, val loss 1.4543
# step 4900: train loss 1.4060, val loss 1.4407
# step 5000: train loss 1.4091, val loss 1.4455
# step 5100: train loss 1.3926, val loss 1.4315
# step 5200: train loss 1.3955, val loss 1.4306
# step 5300: train loss 1.3883, val loss 1.4263
# step 5400: train loss 1.3818, val loss 1.4228
# step 5500: train loss 1.3796, val loss 1.4178
# step 5600: train loss 1.3833, val loss 1.4190
# step 5700: train loss 1.3746, val loss 1.4133
# step 5800: train loss 1.3665, val loss 1.4056
# step 5900: train loss 1.3659, val loss 1.4055
# step 6000: train loss 1.3624, val loss 1.4030
# step 6100: train loss 1.3537, val loss 1.3971
# step 6200: train loss 1.3567, val loss 1.3964
# step 6300: train loss 1.3534, val loss 1.3952
# step 6400: train loss 1.3472, val loss 1.3811
# step 6500: train loss 1.3472, val loss 1.3846
# step 6600: train loss 1.3396, val loss 1.3783
# step 6700: train loss 1.3423, val loss 1.3811
# step 6800: train loss 1.3413, val loss 1.3774
# step 6900: train loss 1.3334, val loss 1.3757
# step 7000: train loss 1.3297, val loss 1.3681
# step 7100: train loss 1.3246, val loss 1.3658
# step 7200: train loss 1.3201, val loss 1.3647
# step 7300: train loss 1.3297, val loss 1.3717
# step 7400: train loss 1.3206, val loss 1.3581
# step 7500: train loss 1.3144, val loss 1.3536
# step 7600: train loss 1.3171, val loss 1.3593
# step 7700: train loss 1.3106, val loss 1.3533
# step 7800: train loss 1.3109, val loss 1.3545
# step 7900: train loss 1.3120, val loss 1.3560
# step 8000: train loss 1.3097, val loss 1.3486
# step 8100: train loss 1.3048, val loss 1.3464
# step 8200: train loss 1.3094, val loss 1.3496
# step 8300: train loss 1.3024, val loss 1.3453
# step 8400: train loss 1.3003, val loss 1.3398
# step 8500: train loss 1.2934, val loss 1.3378
# step 8600: train loss 1.2969, val loss 1.3461
# step 8700: train loss 1.2908, val loss 1.3347
# step 8800: train loss 1.2879, val loss 1.3286
# step 8900: train loss 1.2875, val loss 1.3328
# step 9000: train loss 1.2856, val loss 1.3278
# step 9100: train loss 1.2799, val loss 1.3258
# step 9200: train loss 1.2857, val loss 1.3306
# step 9300: train loss 1.2882, val loss 1.3329
# step 9400: train loss 1.2824, val loss 1.3255
# step 9500: train loss 1.2873, val loss 1.3292
# step 9600: train loss 1.2749, val loss 1.3205
# step 9700: train loss 1.2717, val loss 1.3184
# step 9800: train loss 1.2747, val loss 1.3179
# step 9900: train loss 1.2935, val loss 1.3345
# step 10000: train loss 1.2749, val loss 1.3194
# step 10100: train loss 1.2626, val loss 1.3142
# step 10200: train loss 1.2707, val loss 1.3140
# step 10300: train loss 1.2713, val loss 1.3151
# step 10400: train loss 1.2669, val loss 1.3130
# step 10500: train loss 1.2654, val loss 1.3126
# step 10600: train loss 1.2531, val loss 1.3010
# step 10700: train loss 1.2616, val loss 1.3094
# step 10800: train loss 1.2588, val loss 1.3077
# step 10900: train loss 1.2640, val loss 1.3068
# step 11000: train loss 1.2603, val loss 1.3082
# step 11100: train loss 1.2589, val loss 1.3063
# step 11200: train loss 1.2610, val loss 1.3035
# step 11300: train loss 1.2566, val loss 1.3045
# step 11400: train loss 1.2590, val loss 1.3067
# step 11500: train loss 1.2428, val loss 1.2973
# step 11600: train loss 1.2527, val loss 1.3000
# step 11700: train loss 1.2454, val loss 1.2982
# step 11800: train loss 1.2446, val loss 1.2991
# step 11900: train loss 1.2524, val loss 1.2995
# step 12000: train loss 1.2452, val loss 1.2934
# step 12100: train loss 1.2445, val loss 1.2895
# step 12200: train loss 1.2492, val loss 1.2988
# step 12300: train loss 1.2422, val loss 1.2923
# step 12400: train loss 1.2452, val loss 1.2909
# step 12500: train loss 1.2389, val loss 1.2890
# step 12600: train loss 1.2389, val loss 1.2897
# step 12700: train loss 1.2402, val loss 1.2901
# step 12800: train loss 1.2370, val loss 1.2887
# step 12900: train loss 1.2384, val loss 1.2881
# step 13000: train loss 1.2339, val loss 1.2879
# step 13100: train loss 1.2319, val loss 1.2834
# step 13200: train loss 1.2335, val loss 1.2821
# step 13300: train loss 1.2333, val loss 1.2851
# step 13400: train loss 1.2306, val loss 1.2813
# step 13500: train loss 1.2384, val loss 1.2819
# step 13600: train loss 1.2265, val loss 1.2732
# step 13700: train loss 1.2309, val loss 1.2789
# step 13800: train loss 1.2291, val loss 1.2785
# step 13900: train loss 1.2314, val loss 1.2843
# step 14000: train loss 1.2208, val loss 1.2725
# step 14100: train loss 1.2270, val loss 1.2817
# step 14200: train loss 1.2281, val loss 1.2758
# step 14300: train loss 1.2196, val loss 1.2702
# step 14400: train loss 1.2307, val loss 1.2792
# step 14500: train loss 1.2193, val loss 1.2686
# step 14600: train loss 1.2238, val loss 1.2774
# step 14700: train loss 1.2210, val loss 1.2680
# step 14800: train loss 1.2184, val loss 1.2685
# step 14900: train loss 1.2223, val loss 1.2723
# step 15000: train loss 1.2206, val loss 1.2697
# step 15100: train loss 1.2199, val loss 1.2732
# step 15200: train loss 1.2215, val loss 1.2705
# step 15300: train loss 1.2184, val loss 1.2660
# step 15400: train loss 1.2153, val loss 1.2711
# step 15500: train loss 1.2220, val loss 1.2747
# step 15600: train loss 1.2091, val loss 1.2631
# step 15700: train loss 1.2112, val loss 1.2630
# step 15800: train loss 1.2154, val loss 1.2641
# step 15900: train loss 1.2151, val loss 1.2636
# step 16000: train loss 1.2145, val loss 1.2677
# step 16100: train loss 1.2071, val loss 1.2590
# step 16200: train loss 1.2135, val loss 1.2631
# step 16300: train loss 1.2141, val loss 1.2619
# step 16400: train loss 1.2159, val loss 1.2652
# step 16500: train loss 1.2062, val loss 1.2604
# step 16600: train loss 1.2067, val loss 1.2618
# step 16700: train loss 1.2077, val loss 1.2551
# step 16800: train loss 1.2034, val loss 1.2583
# step 16900: train loss 1.2012, val loss 1.2562
# step 17000: train loss 1.2028, val loss 1.2525
# step 17100: train loss 1.2034, val loss 1.2548
# step 17200: train loss 1.2112, val loss 1.2633
# step 17300: train loss 1.2059, val loss 1.2531
# step 17400: train loss 1.2013, val loss 1.2573
# step 17500: train loss 1.1974, val loss 1.2542
# step 17600: train loss 1.1999, val loss 1.2525
# step 17700: train loss 1.2002, val loss 1.2555
# step 17800: train loss 1.1940, val loss 1.2489
# step 17900: train loss 1.1945, val loss 1.2518
# step 18000: train loss 1.1970, val loss 1.2473
# step 18100: train loss 1.1982, val loss 1.2493
# step 18200: train loss 1.1931, val loss 1.2465
# step 18300: train loss 1.1967, val loss 1.2480
# step 18400: train loss 1.1944, val loss 1.2471
# step 18500: train loss 1.1974, val loss 1.2512
# step 18600: train loss 1.1937, val loss 1.2420
# step 18700: train loss 1.2001, val loss 1.2468
# step 18800: train loss 1.1955, val loss 1.2527
# step 18900: train loss 1.1923, val loss 1.2489
# step 19000: train loss 1.1950, val loss 1.2425
# step 19100: train loss 1.1948, val loss 1.2453
# step 19200: train loss 1.1884, val loss 1.2424
# step 19300: train loss 1.1909, val loss 1.2462
